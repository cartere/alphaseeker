# %%
import pandas as pd
import numpy as np
from matplotlib.ticker import FuncFormatter
from matplotlib.ticker import FormatStrFormatter
import matplotlib.pyplot as plt
# %matplotlib inline
file= r'T:\Operations\Personal\Carter E\Python Docs\USDSwapRates.xlsx'
USSW1 = pd.read_excel(file,
                    sheetname="USSW1",
                  parse_cols=[0,1],
                    header=[0,1]
                   )

USSW2 = pd.read_excel(file,
                    sheetname="USSW2",
                  parse_cols=[0,1],
                    header=[0,1]
                   )
USSW3 = pd.read_excel(file,
                    sheetname="USSW3",
                  parse_cols=[0,1],
                    header=[0,1]
                   )
USSW4 = pd.read_excel(file,
                    sheetname="USSW4",
                  parse_cols=[0,1],
                    header=[0,1]
                   )
USSW5 = pd.read_excel(file,
                    sheetname="USSW5",
                  parse_cols=[0,1],
                    header=[0,1]
                   )
USSW6 = pd.read_excel(file,
                    sheetname="USSW6",
                  parse_cols=[0,1],
                    header=[0,1]
                   )

USSW7 = pd.read_excel(file,
                    sheetname="USSW7",
                  parse_cols=[0,1],
                    header=[0,1]
                   )
USSW8 = pd.read_excel(file,
                    sheetname="USSW8",
                  parse_cols=[0,1],
                    header=[0,1]
                   )

USSW9 = pd.read_excel(file,
                    sheetname="USSW9",
                  parse_cols=[0,1],
                    header=[0,1]
                   )

USSW10 = pd.read_excel(file,
                    sheetname="USSW10",
                  parse_cols=[0,1],
                    header=[0,1]
                   )

USSW11 = pd.read_excel(file,
                    sheetname="USSW11",
                  parse_cols=[0,1],
                    header=[0,1]
                   )

USSW12 = pd.read_excel(file,
                    sheetname="USSW12",
                  parse_cols=[0,1],
                    header=[0,1]
                   )

USSW13 = pd.read_excel(file,
                    sheetname="USSW13",
                  parse_cols=[0,1],
                    header=[0,1]
                   )

USSW14 = pd.read_excel(file,
                    sheetname="USSW14",
                  parse_cols=[0,1],
                    header=[0,1]
                   )

USSW15 = pd.read_excel(file,
                    sheetname="USSW15",
                  parse_cols=[0,1],
                    header=[0,1]
                   )

USSW16 = pd.read_excel(file,
                    sheetname="USSW16",
                  parse_cols=[0,1],
                    header=[0,1]
                   )

USSW17 = pd.read_excel(file,
                    sheetname="USSW17",
                  parse_cols=[0,1],
                    header=[0,1]
                   )

USSW18 = pd.read_excel(file,
                    sheetname="USSW18",
                  parse_cols=[0,1],
                    header=[0,1]
                   )

USSW19 = pd.read_excel(file,
                    sheetname="USSW19",
                  parse_cols=[0,1],
                    header=[0,1]
                   )

USSW20 = pd.read_excel(file,
                    sheetname="USSW20",
                  parse_cols=[0,1],
                    header=[0,1]
                   )

USSW25 = pd.read_excel(file,
                    sheetname="USSW25",
                  parse_cols=[0,1],
                    header=[0,1]
                   )

USSW30 = pd.read_excel(file,
                    sheetname="USSW30",
                  parse_cols=[0,1],
                    header=[0,1]
                   )


#inflation indicator too
Inflation = pd.read_excel(file,
                    sheetname="Inflation",
                  parse_cols=[0,1],
                    header=[0,1]
                   )

# %%
file= r'T:\Operations\Personal\Carter E\Python Docs\USDSwapRates.xlsx'
#plots
fig, axes = plt.subplots(figsize=(15,12), sharex=True)
plt.plot(USSW1, label = 'USSW1')
plt.plot(USSW2, label = 'USSW2')
plt.plot(USSW3, label = 'USSW3') 
plt.plot(USSW4, label = 'USSW4')
plt.plot(USSW5, label = 'USSW5')
plt.plot(USSW6, label = 'USSW6')
plt.plot(USSW7, label = 'USSW7')
plt.plot(USSW8, label = 'USSW8')
plt.plot(USSW9, label = 'USSW9')
plt.plot(USSW10, label = 'USSW10')
plt.plot(USSW11, label = 'USSW11')
plt.plot(USSW12, label = 'USSW12')
plt.plot(USSW13, label = 'USSW13')
plt.plot(USSW14, label = 'USSW14')
plt.plot(USSW15, label = 'USSW15')
plt.plot(USSW16, label = 'USSW16')
plt.plot(USSW17, label = 'USSW17')
plt.plot(USSW18, label = 'USSW18')
plt.plot(USSW19, label = 'USSW19')
plt.plot(USSW20, label = 'USSW20')
plt.plot(USSW25, label = 'USSW25')
plt.plot(USSW30, label = 'USSW30')




plt.legend(loc='best')
plt.title('Rates Since 2005')
plt.show();

# %%
fig, axes = plt.subplots(figsize=(15,12), sharex=True)
plt.plot(USSW1, label = 'USSW1')
plt.plot(USSW5, label = 'USSW5')
plt.plot(USSW20, label = 'USSW20')
plt.plot(USSW25, label = 'USSW25')
plt.plot(USSW30, label = 'USSW30')


plt.legend(loc='best')
plt.title('Rates Since 2005')
plt.show();

# %% [markdown]
# By inspection of the swap curve paths above we can see that;
# 1. Prices of swaps are generally moving together,
# 2. Longer dated swap prices are moving in almost complete unison,
# 3. Shorter dated swap price movements are slightly subdued compared to longer dated swap prices,
# 4. Paths are not crossing, so the curve is upward sloping in our period of observation.

# %%
#empty kernal

# %%
#allows you to pick date range to run data from!
start_date = '2013-01-01'
end_date = '2017-09-21'

fig = plt.figure(figsize=(15,9)) 
ax = fig.add_subplot(1,1,1)
ax.plot(USSW1.loc[start_date:end_date, :].index, USSW1.loc[start_date:end_date, 'USSW1 Cur'], label='USSW1')
ax.plot(USSW5.loc[start_date:end_date, :].index, USSW5.loc[start_date:end_date, 'USSW5 Cur'], label='USSW5')
ax.plot(USSW10.loc[start_date:end_date, :].index, USSW10.loc[start_date:end_date, 'USSW10 Cur'], label='USSW10')
ax.plot(USSW25.loc[start_date:end_date, :].index, USSW25.loc[start_date:end_date, 'USSW25 Cur'], label='USSW25')
ax.plot(USSW30.loc[start_date:end_date, :].index, USSW30.loc[start_date:end_date, 'USSW30 Cur'], label='USSW30')
#ax.plot(Inflation.loc[start_date:end_date, :].index, Inflation.loc[start_date:end_date, 'Inflation'], label='USSW30')

ax.legend(loc='best')
ax.set_ylabel('Rate in %')

# %%
#Real Rate Calculator
df = pd.concat([USSW1, Inflation],1,join= 'inner')
df["Real Rate"] = ""
df["Real Rate"] = df['USSW1 Cur'].values - df['Inflation'].values


plt.plot(df['Real Rate'])
plt.title('1 Year Real Rate')

plt.show()

# %%
#Real Rate Calculator
#plot area
fig, axes = plt.subplots(figsize=(15,12), sharex=True)

#1 year
df = pd.concat([USSW1, Inflation],1,join= 'inner')
df["Real Rate"] = ""
df["Real Rate"] = df['USSW1 Cur'].values - df['Inflation'].values

#5 year
df5 = pd.concat([USSW5, Inflation],1,join= 'inner')
df5["Real Rate"] = ""
df5["Real Rate"] = df5['USSW5 Cur'].values - df5['Inflation'].values

#10 Year
df10 = pd.concat([USSW10, Inflation],1,join= 'inner')
df10["Real Rate"] = ""
df10["Real Rate"] = df10['USSW10 Cur'].values - df10['Inflation'].values

#30 year
df30 = pd.concat([USSW30, Inflation],1,join= 'inner')
df30["Real Rate"] = ""
df30["Real Rate"] = df30['USSW30 Cur'].values - df30['Inflation'].values



#dates
start_date1 = '2013-01-01'
end_date1 = '2017-09-21'


#plot area
plt.plot(df30['Real Rate'], label = '30 Year Real Rate')
plt.plot(df10['Real Rate'], label = '10 Year Real Rate')
plt.plot(df5['Real Rate'], label = '5 Year Real Rate')
plt.plot(df['Real Rate'], label = '1 Year Real Rate')

#Axis setup
plt.title('30 Yr Real Rate')
plt.legend()
plt.show()
